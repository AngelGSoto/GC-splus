# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../anac_data/Results_Corrected/all_fields_photometry_COMPLETE_extinction.csv")

# %%
df.columns.tolist()
# Out:
# ['recno',
#  'T17ID',
#  'oldID',
#  'RAJ2000',
#  'DEJ2000',
#  'Prob',
#  'Rgc',
#  'PA',
#  'umag',
#  'gmag',
#  'rmag',
#  'imag',
#  'zmag',
#  'e_umag',
#  's_umag',
#  'e_gmag',
#  's_gmag',
#  'e_rmag',
#  's_rmag',
#  'e_imag',
#  's_imag',
#  'e_zmag',
#  's_zmag',
#  'FIELD',
#  'FLUX_F378_2',
#  'FLUXERR_F378_2',
#  'MAG_F378_2',
#  'MAGERR_F378_2',
#  'SNR_F378_2',
#  'FLUX_F378_3',
#  'FLUXERR_F378_3',
#  'MAG_F378_3',
#  'MAGERR_F378_3',
#  'SNR_F378_3',
#  'FLUX_F395_2',
#  'FLUXERR_F395_2',
#  'MAG_F395_2',
#  'MAGERR_F395_2',
#  'SNR_F395_2',
#  'FLUX_F395_3',
#  'FLUXERR_F395_3',
#  'MAG_F395_3',
#  'MAGERR_F395_3',
#  'SNR_F395_3',
#  'FLUX_F410_2',
#  'FLUXERR_F410_2',
#  'MAG_F410_2',
#  'MAGERR_F410_2',
#  'SNR_F410_2',
#  'FLUX_F410_3',
#  'FLUXERR_F410_3',
#  'MAG_F410_3',
#  'MAGERR_F410_3',
#  'SNR_F410_3',
#  'FLUX_F430_2',
#  'FLUXERR_F430_2',
#  'MAG_F430_2',
#  'MAGERR_F430_2',
#  'SNR_F430_2',
#  'FLUX_F430_3',
#  'FLUXERR_F430_3',
#  'MAG_F430_3',
# ...

# %%
mag_corr_cols = [
    'MAG_F378_3_corr',
    'MAG_F395_3_corr',
    'MAG_F410_3_corr',
    'MAG_F430_3_corr',
    'MAG_F515_3_corr',
    'MAG_F660_3_corr',
    'MAG_F861_3_corr',
    'umag_corr',
    'gmag_corr',
    'rmag_corr',
    'imag_corr',
    'zmag_corr'
]

# %%
id_ = df["T17ID"]=="T17-2520"

# %%
df[id_][mag_corr_cols]
# Out:
#       MAG_F378_3_corr  MAG_F395_3_corr  MAG_F410_3_corr  MAG_F430_3_corr  \
# 209         18.980947        19.055715        18.489003        18.463110
# 4960        18.810042        19.154411        18.286736        18.342653
#
#       MAG_F515_3_corr  MAG_F660_3_corr  MAG_F861_3_corr  umag_corr  gmag_corr  \
# 209         17.977086        17.678231        17.607565   19.40151   18.14656
# 4960        18.247417        17.695748        17.560624   19.40151   18.14656
#
#       rmag_corr  imag_corr  zmag_corr
# 209   17.901935   17.71453  17.710874
# 4960  17.901935   17.71453  17.710874
